# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
file = pd.read_csv("/content/creditcard.csv", on_bad_lines='skip')
# Out:
# <ipython-input-7-59e55457ce85>:1: DtypeWarning: Columns (4,5,6,8,10,12,13,14,15,18,22,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   file = pd.read_csv("/content/creditcard.csv", on_bad_lines='skip')

# %%
file.head(10)
# Out:
#    Time        V1        V2        V3        V4                   V5  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155   -0.338320769942518
# 1   0.0  1.191857  0.266151  0.166480  0.448154   0.0600176492822243
# 2   1.0 -1.358354 -1.340163  1.773209   0.37978   -0.503198133318193
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291  -0.0103088796030823
# 4   2.0 -1.158233  0.877737  1.548718  0.403034   -0.407193377311653
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252     0.42098688077219
# 6   4.0  1.229658  0.141004  0.045371  1.202613    0.191880988597645
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199    0.948934094764157
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526      2.6695986595986
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187     0.49936080649727
#
#          V6        V7        V8        V9  ...       V21                  V22  \
# 0  0.462388  0.239599  0.098698  0.363787  ... -0.018307    0.277837575558899
# ...

# %%
file.describe()
# Out:
#                Time            V1             V2             V3  \
# count  5.555340e+05  5.555340e+05  555534.000000  555531.000000
# mean   2.617071e+11  1.962854e+07      -0.007197      -0.021181
# std    1.904702e+14  1.462996e+10       1.656675       1.509456
# min    0.000000e+00 -5.640751e+01     -72.715728     -48.325589
# 25%    5.656800e+04 -9.189717e-01      -0.607443      -0.916047
# 50%    8.725450e+04  2.322928e-02       0.060680       0.157249
# 75%    1.400330e+05  1.330207e+00       0.801628       1.007185
# max    1.419231e+17  1.090432e+13      22.057729      26.980000
#
#                   V7            V9            V11            V16  \
# count  555528.000000  5.555250e+05  555520.000000  555500.000000
# mean        0.004085 -3.891806e+07      -0.021076       0.002323
# std         1.240447  2.900700e+10       1.039413       1.134350
# min       -43.557242 -2.161994e+13      -4.797473     -14.129855
# ...

# %%
file.isnull().sum()
# Out:
# Time        0
# V1          0
# V2          0
# V3          3
# V4          3
# V5          5
# V6          5
# V7          6
# V8          8
# V9          9
# V10        11
# V11        14
# V12        18
# V13        26
# V14        28
# V15        31
# V16        34
# V17        42
# V18        48
# V19        54
# V20        64
# V21        68
# V22        73
# V23        79
# V24        90
# V25        95
# V26       102
# V27       110
# V28       116
# Amount    125
# Class     136
# dtype: int64

# %%
file['Class'].value_counts()
# Out:
# Class
# 0.0    554470
# 1.0       928
# Name: count, dtype: int64

# %%
normal=file[file.Class==0]

# %%
fraud=file[file.Class==1]

# %%
print(normal.shape)
# Out:
# (554470, 31)

# %%
print(normal.shape)
# Out:
# (554470, 31)

# %%
normal.Amount.describe()
# Out:
# count    554470.000000
# mean         88.886571
# std         251.536665
# min           0.000000
# 25%           5.640000
# 50%          22.300000
# 75%          77.970000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     928.000000
# mean      124.105873
# std       253.020171
# min         0.000000
# 25%         1.000000
# 50%        12.310000
# 75%       106.900000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# Select only numeric columns for the mean calculation
numeric_columns = file.select_dtypes(include=['number']).columns

# Group by 'Class' and compute the mean for numeric columns only
grouped_data = file[numeric_columns].groupby(file['Class']).mean()
print(grouped_data)
# Out:
#                Time        V1        V2        V3        V7        V9  \
# Class
# 0.0    96961.527578  0.014007 -0.013084 -0.009700  0.013213 -0.020708
# 1.0    84879.504310 -4.774604  3.561221 -6.894774 -5.507807 -2.556964
#
#             V11       V16       V17       V19       V20       V21       V23  \
# Class
# 0.0   -0.027851  0.007848  0.000492  0.000940 -0.001196  0.000443  0.001023
# 1.0    3.614346 -4.074457 -6.616817  0.705261  0.367434  0.749596 -0.029131
#
#             V25       V26       V27       V28      Amount  Class
# Class
# 0.0   -0.002972 -0.000933 -0.000573 -0.000199   88.886571    0.0
# 1.0    0.051444  0.034650  0.132985  0.083020  124.105873    1.0

# %%
normal_sample=normal.sample(n=492)

# %%
new_file=pd.concat([normal_sample,fraud],axis=0)

# %%
new_file.head(10)
# Out:
#             Time        V1        V2        V3                 V4  \
# 74435    45578.0  1.160083 -0.086270  0.824109           1.100189
# 444129  142196.0 -1.255970  1.547504 -0.021479          -0.768208
# 549995  168747.0 -0.595260  0.842853  1.061184  -1.34801827139983
# 30237    34923.0 -0.399934  1.102831  0.953493           1.591661
# 39999    29304.0  0.839355 -1.441314  0.366909          -1.203996
# 402535  140486.0 -2.558135  2.489653 -1.428371          -1.065069
# 90776    49652.0 -0.960216  1.140543  1.039647           -0.53618
# 227026   72560.0  1.304463 -0.791797  1.144705          -0.429738
# 429817  146103.0 -0.546949  0.139166 -0.564173          -1.635997
# 153868   63961.0  0.995659 -0.907513  0.724773          -0.594034
#
#                        V5                 V6        V7                  V8  \
# 74435           -0.615584           0.034689 -0.530738            0.116573
# 444129           0.990096           -1.18016  1.594003           -1.008367
# ...

# %%
new_file['Class'].value_counts()
# Out:
# Class
# 1.0    928
# 0.0    492
# Name: count, dtype: int64

# %%
# Convert all columns to numeric values, setting errors to NaN
file = file.apply(pd.to_numeric, errors='coerce')

# Group by 'Class' and calculate the mean for numeric columns only
grouped_data = file.groupby('Class').mean()
print(grouped_data)
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    96961.527578  0.014007 -0.013084 -0.009700 -0.014993  0.008284
# 1.0    84879.504310 -4.774604  3.561221 -6.894774  4.406770 -3.166965
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0   -0.000981  0.013213 -0.000531 -0.020708  ... -0.001196  0.000443
# 1.0   -1.359561 -5.507807  0.543014 -2.556964  ...  0.367434  0.749596
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0    0.003950  0.001023 -0.000106 -0.002972 -0.000933 -0.000573 -0.000199
# 1.0    0.011992 -0.029131 -0.084167  0.051444  0.034650  0.132985  0.083020
#
#            Amount
# Class
# 0.0     88.886571
# 1.0    124.105873
#
# [2 rows x 30 columns]

# %%
X=new_file.drop(columns='Class',axis=1)

# %%
Y=new_file['Class']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
model=LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction=model.predict(X_train)

# %%
training_data_acuracy=accuracy_score(X_train_prediction,Y_train)*100

# %%
print(f"Training Data Accuracy: {training_data_acuracy}%")
# Out:
# Training Data Accuracy: 93.83802816901408%

# %%
X_test_prediction=model.predict(X_test)

# %%
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)*100

# %%
print(f"Test Data Accuracy: {test_data_accuracy}%")
# Out:
# Test Data Accuracy: 91.90140845070422%
